# %% [markdown]
# # Manual add ground truth marks

# %%
from lib.auto import Doer
root = 'univ_07'; name = 'chaves'

# %%
do = Doer(root, name)
# Out:
# Original length: 166

# %%
pre = 0

# %%
fid=88888
sid=-1
fig = plt.figure(figsize=(18, 7))
do.add_mark(fig, sid, fid, pre)
pre = 1
# Out:
#        fid  sid  slide_type  cam_status
# 161  87525   -1           1         -99
# 162  87526   49           1         -99
# 163  88093   49           1         -99
# 164  88094   -1           1         -99
# 165  89000   -1           1         -99
#
# [5 rows x 4 columns]

# %%
#do.save_marks()
